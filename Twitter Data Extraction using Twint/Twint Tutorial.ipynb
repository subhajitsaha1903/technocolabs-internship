# %%
# !pip install nest_asyncio

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint
# Out:
# C:\Users\Subhajit\.conda\envs\mynewtfenv\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Subhajit\.conda\envs\mynewtfenv\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# C:\Users\Subhajit\.conda\envs\mynewtfenv\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# Set up TWINT config
c = twint.Config()
c.Search = "Oneplus 9 pro"

# Custom output format
c.Limit = 3000
c.Pandas = True
twint.run.Search(c)
# Out:
# 1442180029341855747 2021-09-26 23:01:28 +0530 <trippyankit> @oneplus Oppo 9 pro 😂😂😂
# 1442158988586455054 2021-09-26 21:37:51 +0530 <Karan95228084> @FoxTechh I bought two OnePlus 9 Pro great phone but battery backup not so good why?
# 1442158596205260800 2021-09-26 21:36:18 +0530 <FoxTechh> ANY QUESTIONS about the OnePlus 9 Pro after using it for 6 months!? Long Term Review incoming... 🤔 Drop them down below and maybe you'll get featured in a video! 👍  ⏬⏬⏬  #OnePlus9Pro #AskFox  https://t.co/gaKIVY0KKR
# 1442148096662593545 2021-09-26 20:54:34 +0530 <takneek4u> I played this interesting Quiz on Amazon-Play games at Amazon FunZone  Check Winners on 15th Oct, 2021 OnePlus 9 Pro 5G Quiz #OnePlus9Pro5GQuiz #AmazonGreatIndianFestival #AmazonQuiz #AmazonFunzoneSlots #AmazonSpinandWin #IWonOnAmazon @amazonIN  https://t.co/Jxmul5igSg
# ...

# %%
import pandas as pd
import numpy as np

# %%
def column_names():
    return twint.output.panda.Tweets_df.columns
def twint_to_pd(columns):
    return twint.output.panda.Tweets_df[columns]

# %%
column_names()
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
# tweet_df = twint_to_pd(["date", "username", "tweet", "hashtags", "likes_count"])
# tweet_df = twint_to_pd(["date", "username", "tweet", "hashtags"])
tweet_df = twint_to_pd(["date", "username", "tweet"])

# %%
tweet_df.head(10)
# Out:
#                   date         username  \
# 0  2021-09-26 23:01:28      trippyankit
# 1  2021-09-26 21:37:51    Karan95228084
# 2  2021-09-26 21:36:18         FoxTechh
# 3  2021-09-26 20:54:34        takneek4u
# 4  2021-09-26 20:49:22     AsifAnkalagi
# 5  2021-09-26 20:37:20        SpanouVFX
# 6  2021-09-26 20:09:17          dogs559
# 7  2021-09-26 20:06:04      legend_akay
# 8  2021-09-26 19:51:06         DomusWeb
# 9  2021-09-26 19:42:29  IN_shoppingDeal
#
#                                                tweet
# 0                            @oneplus Oppo 9 pro 😂😂😂
# 1  @FoxTechh I bought two OnePlus 9 Pro great pho...
# 2  ANY QUESTIONS about the OnePlus 9 Pro after us...
# 3  I played this interesting Quiz on Amazon-Play ...
# 4  @amazonIN This festival season I would be upgr...
# 5                             @Grozafn Oneplus 9 pro
# 6  @BureauRussell I carry the tab s7 5g, s21 ultr...
# 7  @voiceyadav redmi note 9yaa  note 9  pro   yaa...
# ...

# %%
# saving the dataframe
tweet_df.to_csv('file1.csv')

# %%
newdf = pd.read_csv("file1.csv")

# %%
newdf.head()
# Out:
#    Unnamed: 0                 date       username  \
# 0           0  2021-09-26 23:01:28    trippyankit
# 1           1  2021-09-26 21:37:51  Karan95228084
# 2           2  2021-09-26 21:36:18       FoxTechh
# 3           3  2021-09-26 20:54:34      takneek4u
# 4           4  2021-09-26 20:49:22   AsifAnkalagi
#
#                                                tweet
# 0                            @oneplus Oppo 9 pro 😂😂😂
# 1  @FoxTechh I bought two OnePlus 9 Pro great pho...
# 2  ANY QUESTIONS about the OnePlus 9 Pro after us...
# 3  I played this interesting Quiz on Amazon-Play ...
# 4  @amazonIN This festival season I would be upgr...
